# %%
import pandas as pd

# %%
df = pd.DataFrame({
    'gender': ['male', 'male', 'female', 'female', 'male', 'female', 'male', 'female'],
    'education_level': ['high school', 'college', 'college', 'graduate', 'high school', 'graduate', 'college', 'graduate'],
    'score': [75, 82, 88, 95, 69, 92, 78, 85]
})

# %%
car=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/cardekho_dataset.csv')

# %%
car
# Out:
#        Unnamed: 0         car_name     brand     model  vehicle_age  \
# 0               0      Maruti Alto    Maruti      Alto            9
# 1               1    Hyundai Grand   Hyundai     Grand            5
# 2               2      Hyundai i20   Hyundai       i20           11
# 3               3      Maruti Alto    Maruti      Alto            9
# 4               4    Ford Ecosport      Ford  Ecosport            6
# ...           ...              ...       ...       ...          ...
# 15406       19537      Hyundai i10   Hyundai       i10            9
# 15407       19540    Maruti Ertiga    Maruti    Ertiga            2
# 15408       19541      Skoda Rapid     Skoda     Rapid            6
# 15409       19542  Mahindra XUV500  Mahindra    XUV500            5
# 15410       19543       Honda City     Honda      City            2
#
#        km_driven seller_type fuel_type transmission_type  mileage  engine  \
# 0         120000  Individual    Petrol            Manual    19.70     796
# ...

# %%
pd.crosstab(car.brand,car.seller_type)
# Out:
# seller_type    Dealer  Individual  Trustmark Dealer
# brand
# Audi              167          25                 0
# BMW               387          52                 0
# Bentley             3           0                 0
# Datsun             69         101                 0
# Ferrari             1           0                 0
# Force               0           1                 0
# Ford              491         290                 9
# Honda            1063         408                14
# Hyundai          1804        1126                52
# ISUZU               2           0                 0
# Isuzu               3           5                 0
# Jaguar             51           8                 0
# Jeep               29          12                 0
# Kia                23           9                 0
# Land Rover         44           7                 0
# Lexus              10           0                 0
# MG                 19           0                 0
# ...

# %%
car.value_counts('brand')
# Out:
# brand
# Maruti           4992
# Hyundai          2982
# Honda            1485
# Mahindra         1011
# Toyota            793
# Ford              790
# Volkswagen        620
# Renault           536
# BMW               439
# Tata              430
# Mercedes-Benz     337
# Skoda             334
# Audi              192
# Datsun            170
# Jaguar             59
# Land Rover         51
# Jeep               41
# Kia                32
# Porsche            21
# Volvo              20
# MG                 19
# Mini               17
# Nissan             11
# Lexus              10
# Isuzu               8
# Bentley             3
# Maserati            2
# ISUZU               2
# Mercedes-AMG        1
# Rolls-Royce         1
# Force               1
# Ferrari             1
# dtype: int64

# %%
car.brand.nunique()
# Out:
# 32

# %%
df = pd.DataFrame({
    'gender': ['male', 'male', 'female', 'female', 'male', 'female', 'male', 'female'],
    'education_level': ['high school', 'college', 'college', 'graduate', 'high school', 'graduate', 'college', 'graduate'],
    'score': [75, 82, 88, 95, 69, 92, 78, 85]
})

# %%
df
# Out:
#    gender education_level  score
# 0    male     high school     75
# 1    male         college     82
# 2  female         college     88
# 3  female        graduate     95
# 4    male     high school     69
# 5  female        graduate     92
# 6    male         college     78
# 7  female        graduate     85

# %%
ct=pd.crosstab(df.gender,df.education_level)

# %%
ct
# Out:
# education_level  college  graduate  high school
# gender
# female                 1         3            0
# male                   2         0            2

# %%
ct_mean=pd.crosstab(df['gender'], df['education_level'], normalize=True,
                      margins=True)

# %%
ct_mean
# Out:
# education_level  college  graduate  high school  All
# gender
# female             0.125     0.375         0.00  0.5
# male               0.250     0.000         0.25  0.5
# All                0.375     0.375         0.25  1.0

# %%
ct_mean=pd.crosstab(df['gender'], df['education_level'], normalize=True,
                      )

# %%
ct_mean
# Out:
# education_level  college  graduate  high school
# gender
# female             0.125     0.375         0.00
# male               0.250     0.000         0.25

# %%
ct_vis=pd.crosstab(df.gender,df.education_level)
ct_vis.plot(kind='bar',stacked=True)
# Out:
# <Axes: xlabel='gender'>

# %%
ct_vis=pd.crosstab(df.gender,df.education_level)
ct_vis.plot(kind='bar')
# Out:
# <Axes: xlabel='gender'>

# %%
car.brand.describe()
# Out:
# count      15411
# unique        32
# top       Maruti
# freq        4992
# Name: brand, dtype: object

# %%
car.value_counts('brand')
# Out:
# brand
# Maruti           4992
# Hyundai          2982
# Honda            1485
# Mahindra         1011
# Toyota            793
# Ford              790
# Volkswagen        620
# Renault           536
# BMW               439
# Tata              430
# Mercedes-Benz     337
# Skoda             334
# Audi              192
# Datsun            170
# Jaguar             59
# Land Rover         51
# Jeep               41
# Kia                32
# Porsche            21
# Volvo              20
# MG                 19
# Mini               17
# Nissan             11
# Lexus              10
# Isuzu               8
# Bentley             3
# Maserati            2
# ISUZU               2
# Mercedes-AMG        1
# Rolls-Royce         1
# Force               1
# Ferrari             1
# dtype: int64

# %%
car.vehicle_age.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
car.brand.value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
data={"name":["Bill","Tom","Tim","John","Alex","Vanessa","Kate"],
      "score":[90,80,85,75,95,60,65],
      "sport":["Wrestling","Football","Skiing","Swimming","Tennis",
               "Karete","Surfing"],
      "gender":["M","M","M","M","F","F","F"]}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#       name  score      sport gender
# 0     Bill     90  Wrestling      M
# 1      Tom     80   Football      M
# 2      Tim     85     Skiing      M
# 3     John     75   Swimming      M
# 4     Alex     95     Tennis      F
# 5  Vanessa     60     Karete      F
# 6     Kate     65    Surfing      F

# %%
df=pd.DataFrame(data,columns=["name","sport","gender","score"])

# %%
df
# Out:
#       name      sport gender  score
# 0     Bill  Wrestling      M     90
# 1      Tom   Football      M     80
# 2      Tim     Skiing      M     85
# 3     John   Swimming      M     75
# 4     Alex     Tennis      F     95
# 5  Vanessa     Karete      F     60
# 6     Kate    Surfing      F     65

# %%
df.head()
# Out:
#    name      sport gender  score
# 0  Bill  Wrestling      M     90
# 1   Tom   Football      M     80
# 2   Tim     Skiing      M     85
# 3  John   Swimming      M     75
# 4  Alex     Tennis      F     95

# %%
df.tail()
# Out:
#       name     sport gender  score
# 2      Tim    Skiing      M     85
# 3     John  Swimming      M     75
# 4     Alex    Tennis      F     95
# 5  Vanessa    Karete      F     60
# 6     Kate   Surfing      F     65

# %%
df.tail(3)
# Out:
#       name    sport gender  score
# 4     Alex   Tennis      F     95
# 5  Vanessa   Karete      F     60
# 6     Kate  Surfing      F     65

# %%
df=pd.DataFrame(data,columns=["name","sport","gender","score","age"])

# %%
df
# Out:
#       name      sport gender  score  age
# 0     Bill  Wrestling      M     90  NaN
# 1      Tom   Football      M     80  NaN
# 2      Tim     Skiing      M     85  NaN
# 3     John   Swimming      M     75  NaN
# 4     Alex     Tennis      F     95  NaN
# 5  Vanessa     Karete      F     60  NaN
# 6     Kate    Surfing      F     65  NaN

# %%
df=pd.DataFrame(data,columns=["name","sport","gender","score","age"],
                index=["ek","do","tin","char","panch","che","saat"])

# %%
df
# Out:
#           name      sport gender  score  age
# ek        Bill  Wrestling      M     90  NaN
# do         Tom   Football      M     80  NaN
# tin        Tim     Skiing      M     85  NaN
# char      John   Swimming      M     75  NaN
# panch     Alex     Tennis      F     95  NaN
# che    Vanessa     Karete      F     60  NaN
# saat      Kate    Surfing      F     65  NaN

# %%
df["gender"]
# Out:
# ek       M
# do       M
# tin      M
# char     M
# panch    F
# che      F
# saat     F
# Name: gender, dtype: object

# %%
mera_columns=["name","score"]
df[mera_columns]
# Out:
#           name  score
# ek        Bill     90
# do         Tom     80
# tin        Tim     85
# char      John     75
# panch     Alex     95
# che    Vanessa     60
# saat      Kate     65

# %%
mera_columns
# Out:
# ['name', 'score']

# %%
df.sport
# Out:
# ek       Wrestling
# do        Football
# tin         Skiing
# char      Swimming
# panch       Tennis
# che         Karete
# saat       Surfing
# Name: sport, dtype: object

# %%
df
# Out:
#           name      sport gender  score  age
# ek        Bill  Wrestling      M     90  NaN
# do         Tom   Football      M     80  NaN
# tin        Tim     Skiing      M     85  NaN
# char      John   Swimming      M     75  NaN
# panch     Alex     Tennis      F     95  NaN
# che    Vanessa     Karete      F     60  NaN
# saat      Kate    Surfing      F     65  NaN

# %%
df.loc[:,'name']
# Out:
# ek          Bill
# do           Tom
# tin          Tim
# char        John
# panch       Alex
# che      Vanessa
# saat        Kate
# Name: name, dtype: object

# %%
df.iloc[:,0]
# Out:
# ek          Bill
# do           Tom
# tin          Tim
# char        John
# panch       Alex
# che      Vanessa
# saat        Kate
# Name: name, dtype: object

# %%
df.iloc[0]
# Out:
# name           Bill
# sport     Wrestling
# gender            M
# score            90
# age             NaN
# Name: ek, dtype: object

# %%
df.loc['ek':'panch']
# Out:
#        name      sport gender  score  age
# ek     Bill  Wrestling      M     90  NaN
# do      Tom   Football      M     80  NaN
# tin     Tim     Skiing      M     85  NaN
# char   John   Swimming      M     75  NaN
# panch  Alex     Tennis      F     95  NaN

# %%
df.loc[['ek','tin'],["name",'gender']]
# Out:
#      name gender
# ek   Bill      M
# tin   Tim      M

# %%
df.loc[:,['name']]
# Out:
#           name
# ek        Bill
# do         Tom
# tin        Tim
# char      John
# panch     Alex
# che    Vanessa
# saat      Kate

# %%
df.loc[['ek','do','tin'],['name','sport','age']]
# Out:
#      name      sport  age
# ek   Bill  Wrestling  NaN
# do    Tom   Football  NaN
# tin   Tim     Skiing  NaN

# %%
df.loc[['ek']]
# Out:
#     name      sport gender  score  age
# ek  Bill  Wrestling      M     90  NaN

# %%
df['age']=18

# %%
df
# Out:
#           name      sport gender  score  age
# ek        Bill  Wrestling      M     90   18
# do         Tom   Football      M     80   18
# tin        Tim     Skiing      M     85   18
# char      John   Swimming      M     75   18
# panch     Alex     Tennis      F     95   18
# che    Vanessa     Karete      F     60   18
# saat      Kate    Surfing      F     65   18

# %%
df=pd.DataFrame(data,columns=["name", "sport", "gender", "score", "age"],
                index=["one","two","three","four","five","six","seven"])
values=[18,19,20,18,17,17,18]
df["age"]=values
df
# Out:
#           name      sport gender  score  age
# one       Bill  Wrestling      M     90   18
# two        Tom   Football      M     80   19
# three      Tim     Skiing      M     85   20
# four      John   Swimming      M     75   18
# five      Alex     Tennis      F     95   17
# six    Vanessa     Karete      F     60   17
# seven     Kate    Surfing      F     65   18

# %%
df["pass"]=df.score>=70

# %%
df
# Out:
#           name      sport gender  score  age   pass
# one       Bill  Wrestling      M     90   18   True
# two        Tom   Football      M     80   19   True
# three      Tim     Skiing      M     85   20   True
# four      John   Swimming      M     75   18   True
# five      Alex     Tennis      F     95   17   True
# six    Vanessa     Karete      F     60   17  False
# seven     Kate    Surfing      F     65   18  False

# %%
del df["pass"]

# %%
scores={"Math":{"A":85,"B":90,"C":95}, "Physics":{"A":90,"B":80,"C":75}}

# %%
scores_df=pd.DataFrame(scores)
scores_df
# Out:
#    Math  Physics
# A    85       90
# B    90       80
# C    95       75

# %%
scores_df.T
# Out:
#           A   B   C
# Math     85  90  95
# Physics  90  80  75

# %%
scores_df.index.name="name"
scores_df.columns.name="lesson"

# %%
scores_df
# Out:
# lesson  Math  Physics
# name
# A         85       90
# B         90       80
# C         95       75

# %%
scores_df.values
# Out:
# array([[85, 90],
#        [90, 80],
#        [95, 75]])

# %%
import pandas as pd

# %%
obj=pd.Series([1,2,3,4,5],
              index=["a","b","c","d","e"])

# %%
obj
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
obj["c"]
# Out:
# 3

# %%
obj[2]
# Out:
# 3

# %%
obj[0:3]
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
obj[['a','c']]
# Out:
# a    1
# c    3
# dtype: int64

# %%
obj[[0,4]]
# Out:
# a    1
# e    5
# dtype: int64

# %%
obj[obj<2]
# Out:
# a    1
# dtype: int64

# %%
obj["a":"e"]
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64
