# %%
import numpy as np

# %%
li=[1,2,3,4]

# %%
type(li)
# Out:
# list

# %%
x=np.array(li
           )

# %%
type(x)
# Out:
# numpy.ndarray

# %%
import pandas as pd
import numpy as np

# %%
data1= np.array([1,None,2,3])

# %%
data1
# Out:
# array([1, None, 2, 3], dtype=object)

# %%
data2= np.array([1,np.nan,3,4])

# %%
data2
# Out:
# array([ 1., nan,  3.,  4.])

# %%
1 + np.nan
# Out:
# nan

# %%
pd.Series([1,np.nan,2,None])
# Out:
# 0    1.0
# 1    NaN
# 2    2.0
# 3    NaN
# dtype: float64

# %%
pd.Series([1,np.nan,2,None])
# Out:
# 0    1.0
# 1    NaN
# 2    2.0
# 3    NaN
# dtype: float64

# %%
x= pd.Series(range(2), dtype=int)

# %%
x
# Out:
# 0    0
# 1    1
# dtype: int64

# %%
x[0] = None

# %%
x
# Out:
# 0    NaN
# 1    1.0
# dtype: float64

# %%
y =pd.Series(range(5),dtype=object)

# %%
y
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: object

# %%
y[0]=None

# %%
y
# Out:
# 0    None
# 1       1
# 2       2
# 3       3
# 4       4
# dtype: object

# %%
pd.Series([1,np.nan,2,None,pd.NA], dtype='Int32')
# Out:
# 0       1
# 1    <NA>
# 2       2
# 3    <NA>
# 4    <NA>
# dtype: Int32

# %%
pd.Series([1,np.nan,2,None,pd.NA], dtype=object)
# Out:
# 0       1
# 1     NaN
# 2       2
# 3    None
# 4    <NA>
# dtype: object

# %%
pd.Series([1,np.nan,2,None], dtype=float)
# Out:
# 0    1.0
# 1    NaN
# 2    2.0
# 3    NaN
# dtype: float64

# %%
data=pd.Series([1,np.nan,'hello',None])

# %%
data
# Out:
# 0        1
# 1      NaN
# 2    hello
# 3     None
# dtype: object

# %%
data.isnull()
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# dtype: bool

# %%
data
# Out:
# 0        1
# 1      NaN
# 2    hello
# 3     None
# dtype: object

# %%
data.notnull()
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
data[data.notnull()]
# Out:
# 0        1
# 2    hello
# dtype: object

# %%
data=pd.Series([1,np.nan,'hello',None])

# %%
data
# Out:
# 0        1
# 1      NaN
# 2    hello
# 3     None
# dtype: object

# %%
data= data.dropna()

# %%
data
# Out:
# 0        1
# 2    hello
# dtype: object

# %%
data=pd.Series([1,np.nan,'hello',None])

# %%
data
# Out:
# 0        1
# 1      NaN
# 2    hello
# 3     None
# dtype: object

# %%
data.fillna(0)
# Out:
# 0        1
# 1        0
# 2    hello
# 3        0
# dtype: object

# %%
data=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Pandas/cardekho_dataset.csv")

# %%
data
# Out:
#        Unnamed: 0         car_name     brand     model  vehicle_age  \
# 0               0      Maruti Alto    Maruti      Alto            9
# 1               1    Hyundai Grand   Hyundai     Grand            5
# 2               2      Hyundai i20   Hyundai       i20           11
# 3               3      Maruti Alto    Maruti      Alto            9
# 4               4    Ford Ecosport      Ford  Ecosport            6
# ...           ...              ...       ...       ...          ...
# 15406       19537      Hyundai i10   Hyundai       i10            9
# 15407       19540    Maruti Ertiga    Maruti    Ertiga            2
# 15408       19541      Skoda Rapid     Skoda     Rapid            6
# 15409       19542  Mahindra XUV500  Mahindra    XUV500            5
# 15410       19543       Honda City     Honda      City            2
#
#        km_driven seller_type fuel_type transmission_type  mileage  engine  \
# 0         120000  Individual    Petrol            Manual    19.70     796
# ...

# %%
data=data.dropna()

# %%
data
# Out:
#        Unnamed: 0         car_name     brand     model  vehicle_age  \
# 0               0      Maruti Alto    Maruti      Alto            9
# 1               1    Hyundai Grand   Hyundai     Grand            5
# 2               2      Hyundai i20   Hyundai       i20           11
# 3               3      Maruti Alto    Maruti      Alto            9
# 4               4    Ford Ecosport      Ford  Ecosport            6
# ...           ...              ...       ...       ...          ...
# 15406       19537      Hyundai i10   Hyundai       i10            9
# 15407       19540    Maruti Ertiga    Maruti    Ertiga            2
# 15408       19541      Skoda Rapid     Skoda     Rapid            6
# 15409       19542  Mahindra XUV500  Mahindra    XUV500            5
# 15410       19543       Honda City     Honda      City            2
#
#        km_driven seller_type fuel_type transmission_type  mileage  engine  \
# 0         120000  Individual    Petrol            Manual    19.70     796
# ...

# %%
noob=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Pandas/netflix_data.csv")

# %%
x
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
x=x.fillna("ullu")

# %%
x
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                  ullu  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
x=x.dropna()

# %%
x
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                  ullu  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
noob.dropna(inplace=True)

# %%
noob
# Out:
#      show_id     type       title           director  \
# 1         s2    Movie        7:19  Jorge Michel Grau
# 2         s3    Movie       23:59       Gilbert Chan
# 3         s4    Movie           9        Shane Acker
# 4         s5    Movie          21     Robert Luketic
# 5         s6  TV Show          46        Serdar Akar
# ...      ...      ...         ...                ...
# 7778   s7779    Movie  Zombieland    Ruben Fleischer
# 7780   s7781    Movie         Zoo       Shlok Sharma
# 7781   s7782    Movie        Zoom       Peter Hewitt
# 7782   s7783    Movie        Zozo        Josef Fares
# 7783   s7784    Movie      Zubaan        Mozez Singh
#
#                                                    cast        country  \
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# ...
