# %% [markdown]
# <a href="https://colab.research.google.com/github/arynch24/Python/blob/main/Day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data1={ "Name": ["Braund, Mr. Owen Harris","Allen, Mr. William Henry","Bonnell, Miss. Elizabeth"],
 "Age": [22, 35, 58],
 "Gender": ["male", "male", "female"]
}

# %%
data1
# Out:
# {'Name': ['Braund, Mr. Owen Harris',
#   'Allen, Mr. William Henry',
#   'Bonnell, Miss. Elizabeth'],
#  'Age': [22, 35, 58],
#  'Gender': ['male', 'male', 'female']}

# %%
type(data1)
# Out:
# dict

# %%
df=pd.DataFrame(data=data1)

# %%
df
# Out:
#                        Name  Age  Gender
# 0   Braund, Mr. Owen Harris   22    male
# 1  Allen, Mr. William Henry   35    male
# 2  Bonnell, Miss. Elizabeth   58  female

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
name=df['Name']

# %%
type(name)
# Out:
# pandas.core.series.Series

# %%
name
# Out:
# 0     Braund, Mr. Owen Harris
# 1    Allen, Mr. William Henry
# 2    Bonnell, Miss. Elizabeth
# Name: Name, dtype: object

# %%
ages=pd.Series([22,23,54], name="Age")

# %%
ages
# Out:
# 0    22
# 1    23
# 2    54
# Name: Age, dtype: int64

# %%
df
# Out:
#                        Name  Age  Gender
# 0   Braund, Mr. Owen Harris   22    male
# 1  Allen, Mr. William Henry   35    male
# 2  Bonnell, Miss. Elizabeth   58  female

# %%
df['Age'].max()
# Out:
# 58

# %%
ages.max(
)
# Out:
# 54

# %%
df.describe()
# Out:
#              Age
# count   3.000000
# mean   38.333333
# std    18.230012
# min    22.000000
# 25%    28.500000
# 50%    35.000000
# 75%    46.500000
# max    58.000000

# %%
country = ["Brazil", "Russia", "India", "China", "South Africa"]
capital = ["Brasilia", "Moscow", "New Delhi", "Beijing", "Pretoria"]
area = [8.516, 17.10, 3.286, 9.67, 2.98]
population = [200.4, 143.5, 1252, 133, 4.3]

# %%
import pandas as pd

# %%
brics=pd.DataFrame(data={'country': country,
                  'capital': capital,
                  'area': area,
                  'population': population})

# %%
brics
# Out:
#         country    capital    area  population
# 0        Brazil   Brasilia   8.516       200.4
# 1        Russia     Moscow  17.100       143.5
# 2         India  New Delhi   3.286      1252.0
# 3         China    Beijing   9.670       133.0
# 4  South Africa   Pretoria   2.980         4.3

# %%
brics.shape
# Out:
# (5, 4)

# %%
brics.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
brics.index=['A','B','C','D','E']

# %%
brics
# Out:
#         country    capital    area  population
# A        Brazil   Brasilia   8.516       200.4
# B        Russia     Moscow  17.100       143.5
# C         India  New Delhi   3.286      1252.0
# D         China    Beijing   9.670       133.0
# E  South Africa   Pretoria   2.980         4.3

# %%
brics.index=range(1,10
              ,2)

# %%
brics
# Out:
#         country    capital    area  population
# 1        Brazil   Brasilia   8.516       200.4
# 3        Russia     Moscow  17.100       143.5
# 5         India  New Delhi   3.286      1252.0
# 7         China    Beijing   9.670       133.0
# 9  South Africa   Pretoria   2.980         4.3

# %%
brics.columns
# Out:
# Index(['country', 'capital', 'area', 'population'], dtype='object')

# %%
c=brics.country

# %%
type(c)
# Out:
# pandas.core.series.Series

# %%
brics
# Out:
#         country    capital    area  population
# 1        Brazil   Brasilia   8.516       200.4
# 3        Russia     Moscow  17.100       143.5
# 5         India  New Delhi   3.286      1252.0
# 7         China    Beijing   9.670       133.0
# 9  South Africa   Pretoria   2.980         4.3

# %%
brics.country
# Out:
# 1          Brazil
# 3          Russia
# 5           India
# 7           China
# 9    South Africa
# Name: country, dtype: object

# %%
c
# Out:
# 1          Brazil
# 3          Russia
# 5           India
# 7           China
# 9    South Africa
# Name: country, dtype: object

# %%
brics[['country']]
# Out:
#         country
# 1        Brazil
# 3        Russia
# 5         India
# 7         China
# 9  South Africa

# %%
a=brics.population

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
brics.index=['A','B','C','D','E']

# %%
brics
# Out:
#         country    capital    area  population
# A        Brazil   Brasilia   8.516       200.4
# B        Russia     Moscow  17.100       143.5
# C         India  New Delhi   3.286      1252.0
# D         China    Beijing   9.670       133.0
# E  South Africa   Pretoria   2.980         4.3

# %%
a
# Out:
# 1     200.4
# 3     143.5
# 5    1252.0
# 7     133.0
# 9       4.3
# Name: population, dtype: float64

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
brics.index
# Out:
# Index(['A', 'B', 'C', 'D', 'E'], dtype='object')

# %%
brics.set_index("country")
# Out:
#                 capital    area  population
# country
# Brazil         Brasilia   8.516       200.4
# Russia           Moscow  17.100       143.5
# India         New Delhi   3.286      1252.0
# China           Beijing   9.670       133.0
# South Africa   Pretoria   2.980         4.3

# %%
brics
# Out:
#         country    capital    area  population
# A        Brazil   Brasilia   8.516       200.4
# B        Russia     Moscow  17.100       143.5
# C         India  New Delhi   3.286      1252.0
# D         China    Beijing   9.670       133.0
# E  South Africa   Pretoria   2.980         4.3

# %%
brics=brics.set_index("country")

# %%
brics
# Out:
#                 capital    area  population
# country
# Brazil         Brasilia   8.516       200.4
# Russia           Moscow  17.100       143.5
# India         New Delhi   3.286      1252.0
# China           Beijing   9.670       133.0
# South Africa   Pretoria   2.980         4.3

# %%
brics.reset_index()
# Out:
#         country    capital    area  population
# 0        Brazil   Brasilia   8.516       200.4
# 1        Russia     Moscow  17.100       143.5
# 2         India  New Delhi   3.286      1252.0
# 3         China    Beijing   9.670       133.0
# 4  South Africa   Pretoria   2.980         4.3

# %%
brics
# Out:
#                 capital    area  population
# country
# Brazil         Brasilia   8.516       200.4
# Russia           Moscow  17.100       143.5
# India         New Delhi   3.286      1252.0
# China           Beijing   9.670       133.0
# South Africa   Pretoria   2.980         4.3

# %%
brics.reset_index(inplace=True)

# %%
brics
# Out:
#         country    capital    area  population
# 0        Brazil   Brasilia   8.516       200.4
# 1        Russia     Moscow  17.100       143.5
# 2         India  New Delhi   3.286      1252.0
# 3         China    Beijing   9.670       133.0
# 4  South Africa   Pretoria   2.980         4.3

# %%
v
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-d0aa4386ac53> in <cell line: 1>()
# ----> 1 v
#
# NameError: name 'v' is not defined

# %%
 brics.set_index("country", inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-2f75a6e5dc3e> in <cell line: 1>()
# ----> 1 brics.set_index("country", inplace = True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    6010
#    6011         if missing:
# -> 6012             raise KeyError(f"None of {missing} are in the columns")
#    6013
#    6014         if inplace:
#
# KeyError: "None of ['country'] are in the columns"

# %%
brics
# Out:
#                 area  population
# country
# Brazil         8.516       200.4
# Russia        17.100       143.5
# India          3.286      1252.0
# China          9.670       133.0
# South Africa   2.980         4.3

# %%
brics.set_index('area')
# Out:
#         population
# area
# 8.516        200.4
# 17.100       143.5
# 3.286       1252.0
# 9.670        133.0
# 2.980          4.3

# %%
brics.reset_index()
# Out:
#         country    area  population
# 0        Brazil   8.516       200.4
# 1        Russia  17.100       143.5
# 2         India   3.286      1252.0
# 3         China   9.670       133.0
# 4  South Africa   2.980         4.3

# %%
brics.set_index("area", inplace=True)

# %%
brics
# Out:
#         population
# area
# 8.516        200.4
# 17.100       143.5
# 3.286       1252.0
# 9.670        133.0
# 2.980          4.3

# %%
# Out:
#      area       0
# 0   8.516   200.4
# 1  17.100   143.5
# 2   3.286  1252.0
# 3   9.670   133.0
# 4   2.980     4.3

# %%
brics.reset_index()
# Out:
#      area       0
# 0   8.516   200.4
# 1  17.100   143.5
# 2   3.286  1252.0
# 3   9.670   133.0
# 4   2.980     4.3

# %%
brics
# Out:
#              0
# area
# 8.516    200.4
# 17.100   143.5
# 3.286   1252.0
# 9.670    133.0
# 2.980      4.3

# %%
country = ["Brazil", "Russia", "India", "China", "South Africa"]
capital = ["Brasilia", "Moscow", "New Delhi", "Beijing", "Pretoria"]
area = [8.516, 17.10, 3.286, 9.67, 2.98]
population = [200.4, 143.5, 1252, 133, 4.3]

# %%
brics=pd.DataFrame(data={'country': country,
                  'capital': capital,
                  'area': area,
                  'population': population})

# %%
brics
# Out:
#         country    capital    area  population
# 0        Brazil   Brasilia   8.516       200.4
# 1        Russia     Moscow  17.100       143.5
# 2         India  New Delhi   3.286      1252.0
# 3         China    Beijing   9.670       133.0
# 4  South Africa   Pretoria   2.980         4.3

# %%
brics.columns = range(4)

# %%
brics
# Out:
#               0          1       2       3
# 0        Brazil   Brasilia   8.516   200.4
# 1        Russia     Moscow  17.100   143.5
# 2         India  New Delhi   3.286  1252.0
# 3         China    Beijing   9.670   133.0
# 4  South Africa   Pretoria   2.980     4.3

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-75-c6bb775d9ab6> in <cell line: 1>()
# ----> 1 brics.columns[1]= "Capital"
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in __setitem__(self, key, value)
#    5300     @final
#    5301     def __setitem__(self, key, value):
# -> 5302         raise TypeError("Index does not support mutable operations")
#    5303
#    5304     def __getitem__(self, key):
#
# TypeError: Index does not support mutable operations

# %%
type(brics.columns)
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
b=list(brics.columns)

# %%
type(b)
# Out:
# list

# %%
b[1]='capital'

# %%
brics.columns=b

# %%
brics
# Out:
#               0    capital       2       3
# 0        Brazil   Brasilia   8.516   200.4
# 1        Russia     Moscow  17.100   143.5
# 2         India  New Delhi   3.286  1252.0
# 3         China    Beijing   9.670   133.0
# 4  South Africa   Pretoria   2.980     4.3

# %%
brics.rename(columns={'country':'count','area':'ar'} , inplace=True)

# %%
brics
# Out:
#               0    capital       2       3
# 0        Brazil   Brasilia   8.516   200.4
# 1        Russia     Moscow  17.100   143.5
# 2         India  New Delhi   3.286  1252.0
# 3         China    Beijing   9.670   133.0
# 4  South Africa   Pretoria   2.980     4.3

# %%
country = ["Brazil", "Russia", "India", "China", "South Africa"]
capital = ["Brasilia", "Moscow", "New Delhi", "Beijing", "Pretoria"]
area = [8.516, 17.10, 3.286, 9.67, 2.98]
population = [200.4, 143.5, 1252, 133, 4.3]

# %%
brics=pd.DataFrame(data={'country': country,
                  'capital': capital,
                  'area': area,
                  'population': population})

# %%
brics
# Out:
#         country    capital    area  population
# 0        Brazil   Brasilia   8.516       200.4
# 1        Russia     Moscow  17.100       143.5
# 2         India  New Delhi   3.286      1252.0
# 3         China    Beijing   9.670       133.0
# 4  South Africa   Pretoria   2.980         4.3

# %%
brics.rename(columns={'country':'count','area':'ar'} , inplace=True)

# %%
brics
# Out:
#           count    capital      ar  population
# 0        Brazil   Brasilia   8.516       200.4
# 1        Russia     Moscow  17.100       143.5
# 2         India  New Delhi   3.286      1252.0
# 3         China    Beijing   9.670       133.0
# 4  South Africa   Pretoria   2.980         4.3

# %%
brics.rename(index={1:'ullu',2:'patha'}, inplace =True)

# %%
brics
# Out:
#               count    capital      ar  population
# 0            Brazil   Brasilia   8.516       200.4
# ullu         Russia     Moscow  17.100       143.5
# patha         India  New Delhi   3.286      1252.0
# 3             China    Beijing   9.670       133.0
# 4      South Africa   Pretoria   2.980         4.3
